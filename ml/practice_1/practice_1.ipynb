# %% [markdown]
# ## TASK 1

# %%
import numpy as np

data_file = open('ex1data1.txt', 'r')

populations = []
profits = []

for line in data_file:
    population, profit = line.split(',')
    populations.append(float(population))
    profits.append(float(profit))

data = {
    'populations': np.array(populations),
    'profits': np.array(profits)
}

data_file.close()

# %%
import matplotlib.pyplot as plt

plt.scatter(data['populations'], data['profits'])
plt.show()

# %%
def computeCost(X, y, theta):
    m = X.shape[0]
    predicts = X @ theta
    cost = (1 / (2 * m)) * np.sum((predicts - y) ** 2)
    return cost

m = data['populations'].shape[0]

X = np.column_stack((np.ones(m), data['populations']))
y = data['profits']
theta = np.array([0, 0])

print(computeCost(X, y, theta))
# Out:
# 32.072733877455676

# %%
def gradientDescent(X, y, theta, alpha, iters):
    m = X.shape[0]
    new_theta = theta
    costs = []

    for i in range(iters):
        predicts = X @ new_theta
        new_theta = new_theta - ((alpha / m) * X.T @ (predicts - y))
        cost = computeCost(X, y, new_theta)
        costs.append(cost)
    
    return new_theta, costs


alpha = 0.01
iters = 1000

result_theta = gradientDescent(X, y, theta, alpha, iters)[0]

# %%
import matplotlib.pyplot as plt

plt.scatter(data['populations'], data['profits'])
plt.plot(data['populations'], X @ result_theta, color='r')
plt.show()

# %%
alpha = 0.05
iters = 1000

theta = np.array([0, 0])

results = gradientDescent(X, y, theta, alpha, iters)
print('Theta: ', results[0], '\nCost: ', results[1][-1])
# Out:
# Theta:  [nan nan]
# Cost:  nan
# /home/psyhack/anaconda3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /tmp/ipykernel_2491/131265284.py:4: RuntimeWarning: overflow encountered in square
#   cost = (1 / (2 * m)) * np.sum((predicts - y) ** 2)
# /tmp/ipykernel_2491/131265284.py:3: RuntimeWarning: overflow encountered in matmul
#   predicts = X @ theta
# /tmp/ipykernel_2491/2122726038.py:7: RuntimeWarning: overflow encountered in matmul
#   predicts = X @ new_theta
# /tmp/ipykernel_2491/2122726038.py:8: RuntimeWarning: invalid value encountered in subtract
#   new_theta = new_theta - ((alpha / m) * X.T @ (predicts - y))

# %% [markdown]
# ## Task 2

# %%
data_file = open('ex1data2.txt', 'r')

sizes = []
bedrooms = []
prices = []

for line in data_file:
    size, bedroom, price = line.split(',')
    sizes.append(int(size))
    bedrooms.append(int(bedroom))
    prices.append(int(price))
    
data_file.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[82], line 9
#       7 for line in data_file:
#       8     print(line)
# ----> 9     size, bedroom, price = line.split(',')
#      10     sizes.append(int(size))
#      11     bedrooms.append(int(bedroom))
#
# ValueError: not enough values to unpack (expected 3, got 1)

# %%
sizes_mean = np.mean(sizes)
sizes_std = np.std(sizes)
normalized_sizes = [(size - sizes_mean) / sizes_std for size in sizes]

bedrooms_mean = np.mean(bedrooms)
bedrooms_std = np.std(bedrooms)
normalized_bedrooms = [(bedroom - bedrooms_mean) / bedrooms_std for bedroom in bedrooms]

prices_mean = np.mean(prices)
prices_std = np.std(prices)
normalized_prices = [(price - prices_mean) / prices_std for price in prices]

ndata = {
    'sizes': np.array(normalized_sizes),
    'bedrooms': np.array(normalized_bedrooms),
    'prices': np.array(normalized_prices),
}
# Out:
# /home/psyhack/anaconda3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/psyhack/anaconda3/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/psyhack/anaconda3/lib/python3.10/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/psyhack/anaconda3/lib/python3.10/site-packages/numpy/core/_methods.py:223: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /home/psyhack/anaconda3/lib/python3.10/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
